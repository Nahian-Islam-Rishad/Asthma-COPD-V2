# %%
import pandas as pd
print(pd.read_csv("../results/imputation_sensitivity.csv").round(4).to_string())
cmp = pd.read_csv("../results/shap_feno_sensitivity.csv")
print(cmp[cmp.feature.str.contains("feno|eosinophil", case=False, na=False)].round(4).to_string(index=False))
# Out:
#                    Model  A_all_cases  A_complete_spx  imputation_effect
# 0          Random Forest       0.9597          0.9377             0.0219
# 1  XGBoost (regularized)       0.9593          0.9358             0.0235
# 2    Logistic Regression       0.9267          0.9108             0.0159
# 3            Extra Trees       0.9114          0.8872             0.0242
# 4                    SVM       0.9009          0.8816             0.0192
#          feature  with_imputed  complete_only  rank_imputed  rank_complete
# eosinophil_count        0.0041         0.0111          21.0           14.0
#   eosinophil_pct        0.0089         0.0168          14.0            8.0
#        feno_mean        0.0197         0.0141           6.0           10.0
